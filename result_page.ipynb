# %%
import pandas as pd
import numpy as np
import cv2
import keras
from sklearn.metrics import classification_report
import pickle

# %%
with open('X_test', 'rb') as f:
    X_test = pickle.load(f)
    
with open('y_test', 'rb') as f:
    y_test = pickle.load(f)

# %%
name_list = ['amir', 'amir_hoseini','ashkan','davari','khara','mohammad',
             'mosadegh','mostafa','nahang','rahim','taherkhoo']

loaded_model = keras.saving.load_model('student_predict1.keras')
    
y_pred = loaded_model.predict(X_test)
y_pred_correct = []
name = ''

for i in range(len(y_pred)):
    value = np.argmax(y_pred[i])
    name = name_list[value]
    y_pred_correct.append(value)
    
#     image = X_test[i]
#     image = cv2.resize(image, (300,300))
#     cv2.imshow(name, image)
#     cv2.waitKey()
#     cv2.destroyAllWindows()
    
print(classification_report(y_true=y_test, y_pred=y_pred_correct))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      0.92      0.96        12
#            2       0.91      1.00      0.95        10
#            3       1.00      1.00      1.00         7
#            4       0.75      1.00      0.86         9
#            5       1.00      1.00      1.00        12
#            6       1.00      1.00      1.00        10
#            7       1.00      0.67      0.80         6
#            8       1.00      0.86      0.92         7
#            9       1.00      1.00      1.00         8
#           10       1.00      1.00      1.00        12
#
#     accuracy                           0.96        99
#    macro avg       0.97      0.95      0.95        99
# weighted avg       0.97      0.96      0.96        99

# %%
#(0:amir) (1:amir_hoseini) (2:ashkan) (3:davari) (4:khara) #(5:mohammad) 
#(6:mosadegh) (7:mostafa) (8:nahang) (9:rahim) (10:taherkhoo)

# %%
img1 = cv2.imread('rahim.jpg')
img1 = cv2.resize(img1, (200,200))
img2 = cv2.imread('mosadegh.jpg')
img2 = cv2.resize(img2, (200,200))
img3 = cv2.imread('taherkhoo.jpg')
img3 = cv2.resize(img3, (200,200))

cv2.imshow('',img3)
cv2.waitKey()
cv2.destroyAllWindows()
img3 = np.expand_dims(img3, axis=0)

print(name_list[np.argmax(loaded_model.predict(img3)[0])])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# taherkhoo
